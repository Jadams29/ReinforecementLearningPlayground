# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np

# %%
df = pd.read_csv("RewardsDuringTraining_Episode_3300.csv", )

# %%
data = df.to_numpy()

# %%
avg = data[:, 1:].mean(axis=1)

# %%
limit=330
df = pd.DataFrame(avg[:limit])
df.plot()
plt.show()
